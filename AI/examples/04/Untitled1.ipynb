# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model


### y = 3x_1 - 2x_2 + 1 のデータを作成

x1 = np.random.rand(100, 1)  # 0 〜 1 までの乱数を 100 個つくる
x1 = x1 * 4 - 2              # 値の範囲を -2 〜 2 に変更

x2 = np.random.rand(100, 1)  # x2 についても同様
x2 = x2 * 4 - 2

y = 3 * x1 - 2 * x2 + 1

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([[ 3., -2.]])

# %%
model.intercept_
# Out:
# array([1.])

# %%
x1_x2
# Out:
# array([[ 0.9793336 ,  0.62755066],
#        [-1.1931272 , -0.34546965],
#        [-0.11076189, -1.46245666],
#        [ 0.82218952,  1.28038772],
#        [-1.20356733,  1.16691726],
#        [-0.62797778, -0.89050063],
#        [ 0.42153008, -1.15175827],
#        [-0.10204653,  1.55554626],
#        [-0.16439644,  1.46942173],
#        [-1.25834294, -1.23132548],
#        [-1.89932776,  1.31882935],
#        [-1.56405317,  0.8828741 ],
#        [-0.23152053,  0.26442473],
#        [ 0.6919826 ,  1.25801691],
#        [-0.58106969, -1.38311601],
#        [ 0.94567622,  1.21121967],
#        [-0.19199234,  1.64605215],
#        [-0.45764423,  0.88203358],
#        [-0.27766725, -1.71810691],
#        [-1.56105062, -1.00314855],
#        [-0.93080213, -1.9818701 ],
#        [-0.45863499, -0.53797485],
#        [-0.38202534, -0.04574313],
#        [-1.63495991,  1.25945035],
#        [ 0.61116329, -1.16718848],
#        [ 1.46122514,  0.01105302],
#        [-0.39389748,  0.73481165],
#        [-1.22695887, -0.64367565],
#        [-1.80961153, -1.22879279],
#        [ 1.9211721 , -0.01991449],
#        [-0.73954483,  1.07530062],
#        [ 1.79685202, -1.11486148],
#        [-0.44916206, -0.83685003],
#        [-0.48204027,  1.9382827 ],
#        [-0.10504992, -1.75647015],
#        [-0.31546592,  0.77236434],
#        [ 0.18670395, -0.96769696],
#        [ 0.06654501, -0.48141246],
#        [-1.95005256,  1.78542724],
#        [-1.08751847, -0.17995863],
#        [-1.73708586,  1.69767682],
#        [ 0.36542829,  1.86159747],
#        [-1.45954636,  0.61487722],
#        [ 1.44747693, -1.44454781],
#        [ 1.99118652,  1.72318957],
#        [-0.90626424, -0.39192517],
#        [ 1.76146987, -0.83772254],
#        [-1.69126902, -1.33074656],
#        [ 0.76238544,  1.95002287],
#        [-0.67439638, -1.07295829],
#        [ 1.81665214, -1.22937615],
#        [-0.68288233, -1.14747736],
#        [-0.10855379,  0.4223635 ],
#        [-1.4288296 , -0.03647872],
#        [-0.70249632,  1.4468732 ],
#        [-0.61074219,  0.10514534],
#        [ 1.18561597, -1.78209407],
#        [-0.66970754,  1.17418706],
#        [-0.29670952, -0.49329676],
#        [ 0.94732718,  1.60227175],
#        [-0.29310666,  1.16829668],
#        [ 0.39093831,  0.80146188],
#        [ 1.75928505,  1.89031011],
#        [ 1.51361119,  1.14391416],
#        [-1.27472735,  0.54855832],
#        [-0.73489198, -0.62364047],
#        [ 0.02509017, -1.16786341],
#        [-1.15740807, -1.37319107],
#        [-1.58436809, -0.47336156],
#        [-1.06046835, -1.00514918],
#        [ 0.74602227, -0.39870096],
#        [-0.96109428,  0.74603714],
#        [-0.34979977,  0.45583855],
#        [ 1.11815835, -1.74647975],
#        [ 0.6316778 ,  1.13822843],
#        [-1.10908034,  0.30903634],
#        [-0.68701625, -0.19243598],
#        [ 0.49750345, -1.65397092],
#        [ 0.15606157,  1.76159208],
#        [-0.54567796, -1.16837885],
#        [-1.83706824, -0.8429278 ],
#        [ 0.3506778 ,  0.46074668],
#        [ 1.88841192, -1.55897683],
#        [ 1.84137116, -0.710841  ],
#        [-0.83167877,  0.33809239],
#        [ 0.74474457,  1.99925267],
#        [ 0.95484528, -0.50638428],
#        [ 0.26908916,  0.0830365 ],
#        [-1.08356882,  1.73819359],
#        [ 1.17184814,  0.85570089],
#        [ 1.79027649, -0.47458404],
#        [-1.52784748, -0.5130297 ],
#        [ 0.65795741,  1.5935592 ],
#        [-1.37024852, -1.12395463],
#        [-1.91773508,  1.70652617],
#        [-0.64510589, -1.38651693],
#        [-1.85856833, -1.18965698],
#        [-1.52772791, -0.03455308],
#        [-0.61762285, -1.15438808],
#        [ 0.53383609,  1.48774455]])
